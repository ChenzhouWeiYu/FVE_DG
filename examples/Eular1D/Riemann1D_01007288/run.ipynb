# %%
# !make
# Out:
# g++  -std=c++17 -O3 -g -march=native -Wall -Wno-unused-variable -Wno-unused-but-set-variable -Wno-comments -fopenmp -mfma -mavx2 -I/home/czwy/Cprogram/FVE_DG/include -I/home/czwy/Cprogram/FVE_DG/external -c Riemann1D.cpp -o Riemann1D.o
# g++ -fopenmp Riemann1D.o /home/czwy/Cprogram/FVE_DG/src/Mesh/ComputingMesh.o /home/czwy/Cprogram/FVE_DG/src/Mesh/DualComputingMesh.o /home/czwy/Cprogram/FVE_DG/src/Mesh/GeneralMesh.o /home/czwy/Cprogram/FVE_DG/src/Mesh/GeneralMeshTools.o /home/czwy/Cprogram/FVE_DG/src/EigenSolver/EigenSparseSolver.o /home/czwy/Cprogram/FVE_DG/src/DG/DG_Schemes/ExplicitConvection.o /home/czwy/Cprogram/FVE_DG/src/DG/DG_Schemes/ImplicitConvection.o /home/czwy/Cprogram/FVE_DG/src/DG/DG_Flux/EulerPhysicalFlux.o -o Riemann1D

# %%
# !./Riemann1D 1 20
# Out:
# Start   0.000000
# Time  0.000649  	sec      Split Hex Mesh to Tet
# Time  0.001254  	sec      Set Init Value
# #       time  rel.err  rho    rel.err  u    rel.err  v    rel.err  w    rel.err  e  rel.err coef      cpu time
# Time  0.022494  	sec      Picard iter 0  55.3361
# Time  0.022558  	sec      Picard iter 0  509.834
# Time  0.044832  	sec      Picard iter 1  49.8855
# Time  0.045203  	sec      Picard iter 1  43.6915
# Time  0.064373  	sec      Picard iter 2  49.6949
# Time  0.064427  	sec      Picard iter 2  5.62823
# Time  0.153720  	sec      Picard iter 3  49.6664
# Time  0.153842  	sec      Picard iter 3  0.935451
# Time  0.180141  	sec      Picard iter 4  49.6612
# Time  0.180200  	sec      Picard iter 4  0.188501
# Time  0.201019  	sec      Picard iter 5  49.6602
# Time  0.201073  	sec      Picard iter 5  0.0889708
# Time  0.224207  	sec      Picard iter 6  49.66
# Time  0.224484  	sec      Picard iter 6  0.082465
# Time  0.246165  	sec      Picard iter 7  49.66
# Time  0.246219  	sec      Picard iter 7  0.0821395
# Time  0.288617  	sec      Picard iter 8  49.66
# Time  0.288674  	sec      Picard iter 8  0.0821219
# Time  0.307380  	sec      Picard iter 9  49.66
# Time  0.307488  	sec      Picard iter 9  0.082121
# Time  0.325460  	sec      Picard iter 10  49.66
# Time  0.325532  	sec      Picard iter 10  0.0821209
# Time  0.361313  	sec      Picard iter 11  49.66
# Time  0.361372  	sec      Picard iter 11  0.0821209
# Time  0.401359  	sec      Picard iter 12  49.66
# Time  0.401425  	sec      Picard iter 12  0.0821209
# Time  0.420927  	sec      Picard iter 13  49.66
# Time  0.420984  	sec      Picard iter 13  0.0821209
# Time  0.440966  	sec      Picard iter 14  49.66
# Time  0.441019  	sec      Picard iter 14  0.0821209
# Time  0.478413  	sec      Picard iter 15  49.66
# Time  0.478483  	sec      Picard iter 15  0.0821209
# Time  0.511622  	sec      Picard iter 16  49.66
# Time  0.511678  	sec      Picard iter 16  0.0821209
# Time  6.435831  	sec      Picard iter 17  35.2874
# Time  6.435885  	sec      Picard iter 17  0.0740354
# Time  6.453839  	sec      Picard iter 18  35.2874
# Time  6.453893  	sec      Picard iter 18  0.0740354
# Time  6.492887  	sec      Picard iter 19  35.2874
# Time  6.492985  	sec      Picard iter 19  0.0740354
# Time  6.531982  	sec      Picard iter 20  35.2874
# Time  6.532057  	sec      Picard iter 20  0.0740354
# Time  6.574018  	sec      Picard iter 21  35.2874
# Time  6.574080  	sec      Picard iter 21  0.0740354
# Time  6.608537  	sec      Picard iter 22  35.2874
# Time  6.608631  	sec      Picard iter 22  0.0740354
# Time  6.630439  	sec      Picard iter 23  35.2874
# Time  6.630491  	sec      Picard iter 23  0.0740354
# Time  6.649588  	sec      Picard iter 24  35.2874
# Time  6.649640  	sec      Picard iter 24  0.0740354
# Time  6.703997  	sec      Picard iter 26  35.2874
# Time  6.704057  	sec      Picard iter 26  0.0740354
# ^C

# %%
# !./Riemann1D 1 20 2>/dev/null
# Out:
# #       time  rel.err  rho    rel.err  u    rel.err  v    rel.err  w    rel.err  e  rel.err coef      cpu time
# ^C

# %%
# !time g++ ./SineWave1D.cpp -o SineWave1D -fopenmp -mfma -mavx2 -O3 -g -I../../
# -march=skylake -mtune=skylake -flto=8 -fomit-frame-pointer -funroll-loops -fno-math-errno -ffast-math

# %%
# !./SineWave1D 2 10

# %%
p = 1
for N in [10,15,20,25,30,40,60,80]:
    # !./SineWave1D {p} {N} 2>/dev/null
p = 2
for N in [10,15,20,25,30,40]:
    # !./SineWave1D {p} {N} 2>/dev/null
p = 3
for N in [10,15,20]:
    # !./SineWave1D {p} {N} 2>/dev/null

# %%
# !./SineWave1D 1 10 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 1 20 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 1 40 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 2 5 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 2 10 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 2 20 2>/dev/null
# draw(1,40,1)

# %%
# !./SineWave1D 2 40 2>/dev/null
# draw(1,40,1)

# %%
# !time g++ ./Riemann1D.cpp -o Riemann1D -fopenmp -mfma -mavx2 -O3 -g -I../../
# -march=skylake -mtune=skylake -flto=8 -fomit-frame-pointer -funroll-loops -fno-math-errno -ffast-math

# %%
# !./Riemann1D 2 10

# %%
# !./Riemann1D 1 84  2>/dev/null
# draw(1,40,1)

# %%
import numpy as np
import scipy 
import matplotlib as mlp
import matplotlib.pyplot as plt 
import os


for p in range(1,6):
    os.mkdir('Order_%d'%(p))

# %%
import subprocess
import time

start = time.time()
N_list = [10,20]
left = 0
right = len(N_list)
p = 1
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,6,8,10,12,]
left = 0
right = len(N_list)
p = 2
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,6,8,]
left = 0
right = len(N_list)
p = 3
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,]
left = 0
right = len(N_list)
p = 4
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import numpy as np
import scipy 
import matplotlib as mlp
import matplotlib.pyplot as plt 
import os


plt.figure(figsize=(10,4),dpi=200)
plt.suptitle('SIP and NIP  with  Picard  rel. tol = 1e-8')
plt.subplot(1,2,1)
plt.title('SIP')
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./stdout_Diric4_%d_%d_1E8.txt'
        if not os.path.exists(filename): continue
        data = np.loadtxt(filename)
        if(len(data)==0): continue
        err = data[5]
        NN.append(N)
        EE.append(err)
    h = 1/np.array(NN)
    error = np.array(EE)
    order = np.diff(np.log(error))/np.diff(np.log(h))
    plt.loglog(h,error,'o-',label='p=%d'%(p))
    gm = lambda x: (x[1:]*x[:-1])**0.5
    for x,y,o in zip(gm(h),gm(error),order):
        plt.text(x,y,o.round(2))
plt.xlabel(r'$h$')
plt.xticks([],minor=True)
plt.xticks([1/v for v in [3,5,8,12,20]],['1/%d'%v for v in [3,5,8,12,20]])
plt.ylabel(r'$\|E_h-E\|/\|E\|$')
plt.grid()
plt.subplot(1,2,2)
plt.title('SIP')
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./logging_Diric4_{p}_{N}_SIP_1E8_stdout.txt'
        if not os.path.exists(filename): continue
        data = np.loadtxt(filename)
        if(len(data)==0): continue
        err = data[5]
        NN.append(N)
        EE.append(err)
    h = 1/np.array(NN)
    error = np.array(EE)
    order = np.diff(np.log(error))/np.diff(np.log(h))
    plt.loglog(h,error,'o-',label='p=%d'%(p))
    gm = lambda x: (x[1:]*x[:-1])**0.5
    for x,y,o in zip(gm(h),gm(error),order):
        plt.text(x,y,o.round(2))

plt.xlabel(r'$h$')
plt.xticks([],minor=True)
plt.xticks([1/v for v in [3,5,8,12,20]],['1/%d'%v for v in [3,5,8,12,20]])
plt.ylabel(r'$\|E_h-E\|/\|E\|$')
plt.grid()
plt.tight_layout()
plt.show()

# %%
p = 2
N = 8
result_file = f'./Order_%d/rho_T_1_N_%d.txt'%(p,N)
rorder_file = f'./logging_Diric4_%d_%d_SIP2_1E8_stdout.txt'%(p,N)
data = np.loadtxt(result_file)
x,y,z, rh,rs, uh,us, vh,vs, wh,ws, eh,es = data.T

plt.figure(figsize=(7,3.2),dpi=200)

plt.subplot(1,2,1)
plt.tripcolor(x,y,eh,cmap='jet')
plt.colorbar()
plt.xticks(np.linspace(0,1,6))
plt.yticks(np.linspace(0,1,6))
plt.xticks(np.linspace(0,1,11),minor=True)
plt.yticks(np.linspace(0,1,11),minor=True)
plt.grid(which='both')
plt.title(r'$E_h(t=\infty)$')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.subplot(1,2,2)
plt.tripcolor(x,y,eh-es,cmap='jet')
plt.colorbar()
plt.xticks(np.linspace(0,1,6))
plt.yticks(np.linspace(0,1,6))
plt.xticks(np.linspace(0,1,11),minor=True)
plt.yticks(np.linspace(0,1,11),minor=True)
plt.grid(which='both')
plt.title(r'$E_h(t=\infty)-E(t=\infty)$')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.suptitle(r'Error of Energy, $\|E_h-E\|/\|E\|$=%.2e'%(
np.loadtxt(rorder_file)[5]))
plt.tight_layout()
plt.show()

# %%
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./logging_Diric4_{p}_{N}_rel1E8_stdout.txt'
        if os.path.exists(filename): 
            os.rename(f'./logging_Diric4_{p}_{N}_rel1E8_stdout.txt',f'./logging_Diric4_{p}_{N}_NIP_1E8_stdout.txt')
            os.rename(f'./logging_Diric4_{p}_{N}_rel1E8_stderr.txt',f'./logging_Diric4_{p}_{N}_NIP_1E8_stderr.txt')
