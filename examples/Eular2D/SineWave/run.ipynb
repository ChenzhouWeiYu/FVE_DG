# %%
# !time g++ ./SineWave2D.cpp -o SineWave2D -fopenmp -mfma -mavx2 -O3 -g -I../../
# -march=skylake -mtune=skylake -flto=8 -fomit-frame-pointer -funroll-loops -fno-math-errno -ffast-math
# Out:
# ^C

# %%
# !./SineWave2D 2 10

# %%
p = 1
for N in [10,15,20,25,30,40,]:
    # !./SineWave2D {p} {N} 2>/dev/null
# p = 2
# for N in [10,15,20,]:
#     !./SineWave2D {p} {N} 2>/dev/null

# %%
# !time g++ ./Riemann2D.cpp -o Riemann2D -fopenmp -mfma -mavx2 -O3 -g -I../../
# -march=skylake -mtune=skylake -flto=8 -fomit-frame-pointer -funroll-loops -fno-math-errno -ffast-math
# Out:
# real	0m55.557s
# user	0m53.783s
# sys	0m1.395s

# %%
# !time g++ ./Sedov.cpp -o Sedov -fopenmp -mfma -mavx2 -O3 -g -I../../

# %%
# !./Sedov 1 10

# %%
# !./Riemann2D 1 10
# 2>/dev/null
# draw(1,40,1)
# Out:
# Start   0.000000
# Time  0.001762  	sec      Split Hex Mesh to Tet
# Time  0.003563  	sec      Set Init Value
# #       time  rel.err  rho    rel.err  u    rel.err  v    rel.err  w    rel.err  e  rel.err coef      cpu time
# Time  0.066385  	sec      Picard iter 0  0.425977
# Time  0.066605  	sec      Picard iter 0  10.7833
# Time  0.115343  	sec      Picard iter 1  0.167188
# Time  0.115485  	sec      Picard iter 1  10.6613
# Time  0.158142  	sec      Picard iter 2  0.163164
# Time  0.158253  	sec      Picard iter 2  10.7044
# Time  0.206229  	sec      Picard iter 3  0.163106
# Time  0.206377  	sec      Picard iter 3  10.7081
# Time  0.251803  	sec      Picard iter 4  0.163101
# Time  0.251905  	sec      Picard iter 4  10.7084
# Time  0.293673  	sec      Picard iter 5  0.163101
# Time  0.293811  	sec      Picard iter 5  10.7084
# Time  0.336487  	sec      Picard iter 6  0.163101
# Time  0.336633  	sec      Picard iter 6  10.7084
# Time  0.382849  	sec      Picard iter 7  0.163101
# Time  0.383005  	sec      Picard iter 7  10.7084
# Time  0.430239  	sec      Picard iter 8  0.163101
# Time  0.430396  	sec      Picard iter 8  10.7084
# Time  0.478737  	sec      Picard iter 9  0.163101
# Time  0.478881  	sec      Picard iter 9  10.7084
# Time  0.525793  	sec      Picard iter 10  0.163101
# Time  0.525978  	sec      Picard iter 10  10.7084
# Time  0.568926  	sec      Picard iter 11  0.163101
# Time  0.569060  	sec      Picard iter 11  10.7084
# Time  0.615554  	sec      Picard iter 12  0.163101
# Time  0.615705  	sec      Picard iter 12  10.7084
# Time  0.669063  	sec      Picard iter 13  0.163101
# Time  0.669224  	sec      Picard iter 13  10.7084
# Time  0.735376  	sec      Picard iter 14  0.163101
# Time  0.735551  	sec      Picard iter 14  10.7084
# Time  0.788740  	sec      Picard iter 15  0.163101
# Time  0.788923  	sec      Picard iter 15  10.7084
# Time  0.829197  	sec      Picard iter 16  0.163101
# Time  7.031300  	sec      Picard iter 57  11.4309
# Time  7.077107  	sec      Picard iter 58  0.17684
# Time  7.077271  	sec      Picard iter 58  11.4309
# Time  7.120571  	sec      Picard iter 59  0.17684
# Time  7.120689  	sec      Picard iter 59  11.4309
# Time  7.165316  	sec      Picard iter 60  0.17684
# Time  7.165421  	sec      Picard iter 60  11.4309
# Time  7.207262  	sec      Picard iter 61  0.17684
# Time  7.207376  	sec      Picard iter 61  11.4309
# Time  7.243634  	sec      Picard iter 62  0.17684
# Time  7.243736  	sec      Picard iter 62  11.4309
# Time  7.286237  	sec      Picard iter 63  0.17684
# Time  7.286350  	sec      Picard iter 63  11.4309
# Time  7.327689  	sec      Picard iter 64  0.17684
# Time  7.327802  	sec      Picard iter 64  11.4309
# Time  7.370023  	sec      Picard iter 65  0.17684
# Time  7.370142  	sec      Picard iter 65  11.4309
# Time  7.409026  	sec      Picard iter 66  0.17684
# Time  7.409183  	sec      Picard iter 66  11.4309
# Time  7.446384  	sec      Picard iter 67  0.17684
# Time  7.446518  	sec      Picard iter 67  11.4309
# Time  7.530063  	sec      Picard iter 69  0.17684
# Time  7.530196  	sec      Picard iter 69  11.4309
# ^C

# %%
import numpy as np
import scipy 
import matplotlib as mlp
import matplotlib.pyplot as plt 
import os


for p in range(1,6):
    os.mkdir('Order_%d'%(p))

# %%
import subprocess
import time

start = time.time()
N_list = [10,20]
left = 0
right = len(N_list)
p = 1
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,6,8,10,12,]
left = 0
right = len(N_list)
p = 2
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,6,8,]
left = 0
right = len(N_list)
p = 3
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import subprocess
import time

start = time.time()
N_list = [3,4,5,]
left = 0
right = len(N_list)
p = 4
for k,N in enumerate(N_list[left:right]):
    # 定义输出文件路径
    stdout_file = f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N)
    stderr_file = f"./stderr_Diric4_%d_%d_1E8.txt"%(p,N)

    # 构造命令
    command = f"./SedovBatch3 {p} {N}"

    # 执行命令并捕获输出
    with open(stdout_file, "w") as out, open(stderr_file, "w") as err:
        process = subprocess.Popen(command, shell=True, stdout=out, stderr=err)
        process.wait()  # 等待进程完成


    draw(p,N)
    result = {}
    NN = []
    EE = []
    for N in N_list[:(left+k+1)]:
        # result[N] = read(stderr_file)
        NN.append(N)
        EE.append(np.loadtxt(f"./stdout_Diric4_%d_%d_1E8.txt"%(p,N))[5])
    print(time.time()-start,NN,EE)
    if(len(NN)>1):
        print(np.diff(np.log(np.array(EE)))/np.diff(np.log(np.array(NN))))

# %%
import numpy as np
import scipy 
import matplotlib as mlp
import matplotlib.pyplot as plt 
import os


plt.figure(figsize=(10,4),dpi=200)
plt.suptitle('SIP and NIP  with  Picard  rel. tol = 1e-8')
plt.subplot(1,2,1)
plt.title('SIP')
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./stdout_Diric4_%d_%d_1E8.txt'
        if not os.path.exists(filename): continue
        data = np.loadtxt(filename)
        if(len(data)==0): continue
        err = data[5]
        NN.append(N)
        EE.append(err)
    h = 1/np.array(NN)
    error = np.array(EE)
    order = np.diff(np.log(error))/np.diff(np.log(h))
    plt.loglog(h,error,'o-',label='p=%d'%(p))
    gm = lambda x: (x[1:]*x[:-1])**0.5
    for x,y,o in zip(gm(h),gm(error),order):
        plt.text(x,y,o.round(2))
plt.xlabel(r'$h$')
plt.xticks([],minor=True)
plt.xticks([1/v for v in [3,5,8,12,20]],['1/%d'%v for v in [3,5,8,12,20]])
plt.ylabel(r'$\|E_h-E\|/\|E\|$')
plt.grid()
plt.subplot(1,2,2)
plt.title('SIP')
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./logging_Diric4_{p}_{N}_SIP_1E8_stdout.txt'
        if not os.path.exists(filename): continue
        data = np.loadtxt(filename)
        if(len(data)==0): continue
        err = data[5]
        NN.append(N)
        EE.append(err)
    h = 1/np.array(NN)
    error = np.array(EE)
    order = np.diff(np.log(error))/np.diff(np.log(h))
    plt.loglog(h,error,'o-',label='p=%d'%(p))
    gm = lambda x: (x[1:]*x[:-1])**0.5
    for x,y,o in zip(gm(h),gm(error),order):
        plt.text(x,y,o.round(2))

plt.xlabel(r'$h$')
plt.xticks([],minor=True)
plt.xticks([1/v for v in [3,5,8,12,20]],['1/%d'%v for v in [3,5,8,12,20]])
plt.ylabel(r'$\|E_h-E\|/\|E\|$')
plt.grid()
plt.tight_layout()
plt.show()

# %%
p = 2
N = 8
result_file = f'./Order_%d/rho_T_1_N_%d.txt'%(p,N)
rorder_file = f'./logging_Diric4_%d_%d_SIP2_1E8_stdout.txt'%(p,N)
data = np.loadtxt(result_file)
x,y,z, rh,rs, uh,us, vh,vs, wh,ws, eh,es = data.T

plt.figure(figsize=(7,3.2),dpi=200)

plt.subplot(1,2,1)
plt.tripcolor(x,y,eh,cmap='jet')
plt.colorbar()
plt.xticks(np.linspace(0,1,6))
plt.yticks(np.linspace(0,1,6))
plt.xticks(np.linspace(0,1,11),minor=True)
plt.yticks(np.linspace(0,1,11),minor=True)
plt.grid(which='both')
plt.title(r'$E_h(t=\infty)$')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.subplot(1,2,2)
plt.tripcolor(x,y,eh-es,cmap='jet')
plt.colorbar()
plt.xticks(np.linspace(0,1,6))
plt.yticks(np.linspace(0,1,6))
plt.xticks(np.linspace(0,1,11),minor=True)
plt.yticks(np.linspace(0,1,11),minor=True)
plt.grid(which='both')
plt.title(r'$E_h(t=\infty)-E(t=\infty)$')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.suptitle(r'Error of Energy, $\|E_h-E\|/\|E\|$=%.2e'%(
np.loadtxt(rorder_file)[5]))
plt.tight_layout()
plt.show()

# %%
for p in range(3):
    p = p+1
    NN = []
    EE = []
    for N in range(30):
        filename = f'./logging_Diric4_{p}_{N}_rel1E8_stdout.txt'
        if os.path.exists(filename): 
            os.rename(f'./logging_Diric4_{p}_{N}_rel1E8_stdout.txt',f'./logging_Diric4_{p}_{N}_NIP_1E8_stdout.txt')
            os.rename(f'./logging_Diric4_{p}_{N}_rel1E8_stderr.txt',f'./logging_Diric4_{p}_{N}_NIP_1E8_stderr.txt')
